# %% [markdown]
# <a href="https://colab.research.google.com/github/tathinasri2007-star/Athinasri2007/blob/main/Final%20project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
import zipfile

uploaded=files.upload()

zip_file_name = next(iter(uploaded))

with zipfile.ZipFile(zip_file_name, 'r') as zf:
    zf.extractall()

df=pd.read_csv("Amazon Sale Report.csv")
print(df)
# Out:
#      <input type="file" id="files-747cb08e-f957-4dfe-a1fd-e64aeda185af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-747cb08e-f957-4dfe-a1fd-e64aeda185af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
print(df.isnull().sum())
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df = df.dropna()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df["Date"] = pd.to_datetime(df["Date"], format='%m-%d-%y')

# %%
df["Month"] = df["Date"].dt.month_name()

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19379 entries, 49051 to 128891
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               19379 non-null  int64
#  1   Order ID            19379 non-null  object
#  2   Date                19379 non-null  datetime64[ns]
#  3   Status              19379 non-null  object
#  4   Fulfilment          19379 non-null  object
#  5   Sales Channel       19379 non-null  object
#  6   ship-service-level  19379 non-null  object
#  7   Style               19379 non-null  object
#  8   SKU                 19379 non-null  object
#  9   Category            19379 non-null  object
#  10  Size                19379 non-null  object
#  11  ASIN                19379 non-null  object
#  12  Courier Status      19379 non-null  object
#  13  Qty                 19379 non-null  int64
#  14  currency            19379 non-null  object
# ...

# %%
print(df.describe())
# Out:
#                index                           Date           Qty  \
# count   19379.000000                          19379  19379.000000
# mean    86650.405542  2022-05-27 22:32:36.881160192      1.004799
# min     49051.000000            2022-04-30 00:00:00      1.000000
# 25%     67813.000000            2022-05-13 00:00:00      1.000000
# 50%     83317.000000            2022-05-25 00:00:00      1.000000
# 75%    105153.500000            2022-06-12 00:00:00      1.000000
# max    128891.000000            2022-06-29 00:00:00      5.000000
# std     22204.535858                            NaN      0.082081
#
#              Amount  ship-postal-code
# count  19379.000000      19379.000000
# mean     673.245162     464618.933743
# min        0.000000     110001.000000
# 25%      471.000000     380058.000000
# 50%      678.000000     500032.000000
# 75%      786.000000     600039.000000
# max     2796.000000     855107.000000
# std      287.866514     191536.937504

# %%
print(df.isnull().sum())
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# B2B                   0
# fulfilled-by          0
# Unnamed: 22           0
# Month                 0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df["Revenue"] = df["Qty"] * df["Amount"]
print(df.head())
# Out:
#        index             Order ID       Date                        Status  \
# 49051  49051  408-4858463-2356347 2022-05-31  Shipped - Delivered to Buyer
# 49077  49077  402-7697834-2682766 2022-05-31  Shipped - Delivered to Buyer
# 49081  49081  402-7031777-0396341 2022-05-31  Shipped - Delivered to Buyer
# 49082  49082  408-1235521-4337163 2022-05-31  Shipped - Delivered to Buyer
# 49083  49083  403-3845187-4421165 2022-05-31  Shipped - Delivered to Buyer
#
#       Fulfilment Sales Channel  ship-service-level    Style             SKU  \
# 49051   Merchant      Amazon.in           Standard    J0385      J0385-KR-M
# 49077   Merchant      Amazon.in           Standard  JNE3654  JNE3654-TP-XXL
# 49081   Merchant      Amazon.in           Standard  JNE3798   JNE3798-KR-XS
# 49082   Merchant      Amazon.in           Standard    J0152      J0152-DR-L
# 49083   Merchant      Amazon.in           Standard    J0157     J0157-DR-XL
#
# ...

# %%
monthly_revenue = df.groupby('Month')['Revenue'].sum().reindex(['April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'January', 'February', 'March'], fill_value=0)

plt.figure(figsize=(12, 6))
monthly_revenue.plot(kind='bar', color='skyblue')
plt.title('Total Revenue by Month')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
monthly_revenue = df.groupby('Month')['Revenue'].sum().reindex(['April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'January', 'February', 'March'])

plt.figure(figsize=(12, 6))
monthly_revenue.plot(kind='bar', color='skyblue')
plt.title('Total Revenue by Month')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
monthly_revenue = df.groupby('Month')['Revenue'].sum().reindex(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'], fill_value=0)

plt.figure(figsize=(12, 6))
monthly_revenue.plot(kind='bar', color='skyblue')
plt.title('Total Revenue by Month')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
monthly_revenue = df.groupby('Month')['Revenue'].sum().reindex(['April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'January', 'February', 'March'], fill_value=0)

plt.figure(figsize=(12, 6))
monthly_revenue.plot(kind='bar', color='skyblue')
plt.title('Total Revenue by Month')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
product_sales = df.groupby("Category")["Revenue"].sum()

print(product_sales)
# Out:
# Category
# Blouse             42488.0
# Bottom             43465.0
# Ethnic Dress      104323.0
# Saree              11429.0
# Set              5958891.0
# Top               733074.0
# Western Dress    3335952.0
# kurta            2951438.0
# Name: Revenue, dtype: float64

# %%
product_sales = df.groupby("Category")["Revenue"].sum()
print(product_sales)
# Out:
# Category
# Blouse             42488.0
# Bottom             43465.0
# Ethnic Dress      104323.0
# Saree              11429.0
# Set              5958891.0
# Top               733074.0
# Western Dress    3335952.0
# kurta            2951438.0
# Name: Revenue, dtype: float64

# %%
product_sales = df.groupby("Category")["Revenue"].sum()

print(product_sales)
# Out:
# Category
# Blouse             42488.0
# Bottom             43465.0
# Ethnic Dress      104323.0
# Saree              11429.0
# Set              5958891.0
# Top               733074.0
# Western Dress    3335952.0
# kurta            2951438.0
# Name: Revenue, dtype: float64

# %%
product_sales = df.groupby("Category")["Revenue"].sum()

print(product_sales)
# Out:
# Category
# Blouse             42488.0
# Bottom             43465.0
# Ethnic Dress      104323.0
# Saree              11429.0
# Set              5958891.0
# Top               733074.0
# Western Dress    3335952.0
# kurta            2951438.0
# Name: Revenue, dtype: float64

# %%
top_products = product_sales.sort_values(ascending=False)

print(top_products)
# Out:
# Category
# Set              5958891.0
# Western Dress    3335952.0
# kurta            2951438.0
# Top               733074.0
# Ethnic Dress      104323.0
# Bottom             43465.0
# Blouse             42488.0
# Saree              11429.0
# Name: Revenue, dtype: float64

# %%
monthly_sales = df.groupby("Month")["Revenue"].sum()

print(monthly_sales)
# Out:
# Month
# April      16615.0
# June     5670407.0
# May      7494038.0
# Name: Revenue, dtype: float64

# %%
total_revenue = df["Revenue"].sum()

print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 13181060.0

# %%
top_products.head(10).plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Top Selling Products")
plt.xlabel("Products")
plt.ylabel("Revenue")
plt.show()

# %%
monthly_sales.plot(
    kind="line",
    marker="o",
    figsize=(10,5)
)

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.grid(True)
plt.show()

# %%
best_product = top_products.idxmax()

print("Best Selling Product:", best_product)
# Out:
# Best Selling Product: Set

# %%
best_month = monthly_sales.idxmax()

print("Peak Sales Month:", best_month)
# Out:
# Peak Sales Month: May

# %%
print("Business Insights")

print("Highest Selling Product:", best_product)
print("Peak Sales Month:", best_month)
print("Total Revenue:", total_revenue)
# Out:
# Business Insights
# Highest Selling Product: Set
# Peak Sales Month: May
# Total Revenue: 13181060.0

# %%
print("E-Commerce Sales Performance Analysis Completed Successfully")
# Out:
# E-Commerce Sales Performance Analysis Completed Successfully

# %%
top_products = product_sales.sort_values(ascending=False)
print(top_products)
# Out:
# Category
# Set              5958891.0
# Western Dress    3335952.0
# kurta            2951438.0
# Top               733074.0
# Ethnic Dress      104323.0
# Bottom             43465.0
# Blouse             42488.0
# Saree              11429.0
# Name: Revenue, dtype: float64
