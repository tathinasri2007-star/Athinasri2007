# %% [markdown]
# <a href="https://colab.research.google.com/github/tathinasri2007-star/Athinasri2007/blob/main/Mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
uploaded=files.upload()
df=pd.read_csv("Product Sales Data (2).csv")
print(df)
# Out:
#      <input type="file" id="files-fc119264-194d-4741-b1d7-94517f791a16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc119264-194d-4741-b1d7-94517f791a16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(12)
# Out:
#    Month  Cream  Detergent  Moisturizer  Sanitizer  Shampoo  Soap  \
# 0    Jan   5100       9600         1525       1550     1200  2510
# 1    Feb   5000       6500         1225       1250     2100  2640
# 2    Mar   4450       9950         1365       1390     3550  2150
# 3    Apr   5770       9270         1155       1180     1870  3410
# 4    May   4460       8160         1765       1790     1560  3610
# 5    Jun   4790       7890         1580       1605     1890  2770
# 6    Jul   4680       9380         1145       1170     1780  2990
# 7    Aug   5760      10360         1425       1450     2860  3710
# 8    Sep   6000       8500         1805       1830     2100  3550
# 9    Oct   8200      10700         1915       1940     2300  2000
# 10   Nov   7200      13700         2125       2150     2400  2350
# 11   Dec   7300      14800         1785       1810     1800  2910
#
#     Total Units  Total Profit
# 0         21485        211500
# 1         18715        183800
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Month         12 non-null     object
#  1   Cream         12 non-null     int64
#  2   Detergent     12 non-null     int64
#  3   Moisturizer   12 non-null     int64
#  4   Sanitizer     12 non-null     int64
#  5   Shampoo       12 non-null     int64
#  6   Soap          12 non-null     int64
#  7   Total Units   12 non-null     int64
#  8   Total Profit  12 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 996.0+ bytes
# None

# %%
print(df.shape)
# Out:
# (12, 9)

# %%
print(df.isnull().sum())
# Out:
# Month           0
# Cream           0
# Detergent       0
# Moisturizer     0
# Sanitizer       0
# Shampoo         0
# Soap            0
# Total Units     0
# Total Profit    0
# dtype: int64

# %%
df=df.drop_duplicates()
print(df)
# Out:
#    Month  Cream  Detergent  Moisturizer  Sanitizer  Shampoo  Soap  \
# 0    Jan   5100       9600         1525       1550     1200  2510
# 1    Feb   5000       6500         1225       1250     2100  2640
# 2    Mar   4450       9950         1365       1390     3550  2150
# 3    Apr   5770       9270         1155       1180     1870  3410
# 4    May   4460       8160         1765       1790     1560  3610
# 5    Jun   4790       7890         1580       1605     1890  2770
# 6    Jul   4680       9380         1145       1170     1780  2990
# 7    Aug   5760      10360         1425       1450     2860  3710
# 8    Sep   6000       8500         1805       1830     2100  3550
# 9    Oct   8200      10700         1915       1940     2300  2000
# 10   Nov   7200      13700         2125       2150     2400  2350
# 11   Dec   7300      14800         1785       1810     1800  2910
#
#     Total Units  Total Profit
# 0         21485        211500
# 1         18715        183800
# ...

# %%
product_sales=df[['Cream','Detergent','Moisturizer','Sanitizer','Shampoo','Soap',]].sum()
print(product_sales)
# Out:
# Cream           68710
# Detergent      118810
# Moisturizer     18815
# Sanitizer       19115
# Shampoo         25410
# Soap            34600
# dtype: int64

# %%
total_sales=df["Total Profit"].sum()
print("total sales:",total_sales)
# Out:
# total sales: 3129300

# %%
product_sales.plot(kind='bar')
plt.title("product sales analysis")
plt.xlabel("products ")
plt.ylabel("total sales")
# Out:
# Text(0, 0.5, 'total sales')
